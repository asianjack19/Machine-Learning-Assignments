# %% [markdown]
# # Case Study 4 (Singapore Airbnb)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# ### Load data from csv

# %%
sgData = pd.read_csv("listings.csv")

# %% [markdown]
# ### Choose Discrete and Continuous Data

# %%
sgDiscreteData=sgData[["minimum_nights", "availability_365"]]
sgContinuousData=sgData[["id", "host_id", "latitude", "longitude", "price", "number_of_reviews", "reviews_per_month", "calculated_host_listings_count"]]

# %% [markdown]
# ### Plot Discrete data histogram and pdf

# %%
sb.distplot(sgDiscreteData["minimum_nights"])
# Out:
# C:\Users\micha\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='minimum_nights', ylabel='Density'>

# %%
sb.distplot(sgDiscreteData["availability_365"])
# Out:
# C:\Users\micha\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='availability_365', ylabel='Density'>

# %% [markdown]
# ### Plot Continuous data histogram and pdf

# %%
sb.distplot(sgContinuousData["id"])
# Out:
# C:\Users\micha\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='id', ylabel='Density'>

# %%
sb.distplot(sgContinuousData["host_id"])
# Out:
# C:\Users\micha\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='host_id', ylabel='Density'>

# %%
sb.distplot(sgContinuousData["latitude"])
# Out:
# C:\Users\micha\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='latitude', ylabel='Density'>

# %%
sb.distplot(sgContinuousData["longitude"])
# Out:
# C:\Users\micha\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='longitude', ylabel='Density'>

# %%
sb.distplot(sgContinuousData["price"])
# Out:
# C:\Users\micha\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sb.distplot(sgContinuousData["number_of_reviews"])
# Out:
# C:\Users\micha\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='number_of_reviews', ylabel='Density'>

# %%
sb.distplot(sgContinuousData["reviews_per_month"])
# Out:
# C:\Users\micha\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='reviews_per_month', ylabel='Density'>

# %%
sb.distplot(sgContinuousData["calculated_host_listings_count"])
# Out:
# C:\Users\micha\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='calculated_host_listings_count', ylabel='Density'>
